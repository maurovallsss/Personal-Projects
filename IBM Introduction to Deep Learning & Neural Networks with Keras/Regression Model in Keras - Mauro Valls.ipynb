# %% [markdown]
# # Regression Model in Keras - Mauro Valls

# %% [markdown]
# What you will see:
# 1. Functions for simplifying processes
# 2. Loading the dataset
# 3. Validating the dataset
# 4. Splitting the dataset into training and testing sets
# 5. Model A - Baseline results
# 6. Normalizing the input features
# 7. Model B - Results after normalization
# 8. Model C - Results with increased epochs
# 9. Model D - Results with three hidden layers
# 10. Final comparative results

# %%
import numpy as np
import pandas as pd
import os
import time
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %% [markdown]
# ## Functions for simplifying processes

# %%
def load_data(file_path):
    """Loads data from a CSV file or from the URL"""
    try:
      # Checks if the file exists locally
        if os.path.isfile(file_path):
            print(f"Loading data from the file'{file_path}'")
            data = pd.read_csv(file_path, header=0)
        else:
            # Load data from the URL if the file is not found locally
            print(f"File not found: {file_path}. Loading from the URL.")
            url = 'https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/DL0101EN/labs/data/concrete_data.csv'
            data = pd.read_csv(url)
        return data
    except Exception as e:
        print(f"Error loading data: {e}")
        return None

def mean(scores):
    """Calculate the average value from a list of scores"""
    # Checks if the list is not empty
    if len(scores) > 0:
        # Calculates the mean and round it to 2 decimal places
        return round(np.mean(scores), 2)
    return None

def standard_deviation(scores):
    """Calculate the standard deviation of a list of scores"""

    # Checks if the list is not empty
    if scores:
         # Calculates the standard deviation and round it to 2 decimal places
        return round(np.std(scores), 2)
    return None

def report(experiment_label, avg_error_value, deviation_value):
    """Generate a summary DataFrame with experiment results."""

    # Creates a dictionary to summarize the results
    result_summary = {
        'Experiment': [experiment_label],
        'Average Error (Mean MSE)': [avg_error_value],
        'Error Deviation (Deviation MSE)': [deviation_value]
    }

    # Converts the dictionary into a pandas DataFrame
    return pd.DataFrame(result_summary)

def model_a(inputs=3):
    """Creates a neural network model with:
    - One hidden layer of 10 nodes with ReLU activation.
    - Adam optimizer and mean squared error as the loss function.
    """

    # Initialize the model (Sequential as layers are added in a linear stack)
    model = Sequential()

    # Add hidden layer with 10 nodes
    model.add(Dense(10, activation="relu", input_shape=(inputs,)))
    # Add the output layer with 1 node
    model.add(Dense(1))
    # Compiles the model with Adam optimizer and mean squared error as the loss
    model.compile(optimizer='adam', loss='mean_squared_error')
    return model

def mean_squared_root_evaluation(trained_model, inputs, target, num_epochs=50, display_output=1):
    # Splits the data into training (70%) and testing (30%) sets
    X_train, X_test, y_train, y_test = train_test_split(inputs, target, test_size=0.3, random_state=24)
    print(f"Training set size: {X_train.shape}, {y_train.shape}")
    print(f"Testing set size: {X_test.shape}, {y_test.shape}")

    # Trains the model using the training data
    trained_model.fit(X_train, y_train, epochs=num_epochs, verbose=display_output)

    # Uses the trained model to predict on the test data
    predictions = trained_model.predict(X_test)

    # Calculates the mean squared error between predictions and actual values
    error = mean_squared_error(y_test, predictions)
    return error

def calculate_error_stats(inputs, target_values, model, iterations=50, epochs=50, verbose=0):
    """Calculate the average and standard deviation of prediction errors"""
    error_list = []
    for round_number in range(iterations):
        # Record the start time of the iteration
        start_time = time.time()
        print("-" * 40)
        print(f"Starting iteration: {round_number + 1}")

        # Evaluate the prediction error for the current iteration
        current_error = mean_squared_root_evaluation(
            trained_model=model,
            inputs=inputs,
            target=target_values,
            num_epochs=epochs,
            display_output=verbose
        )
        # Appends the error to the list
        error_list.append(current_error)
        print(f"Iteration finished in {time.time() - start_time:.2f} seconds.")

    print(f"Completed {iterations} iterations. Error list: {error_list}")

    # Calculates the average error
    average_error = mean(error_list)
    # Calculate the standard deviation of the errors
    error_std_dev = standard_deviation(error_list)

    print("-" * 70)
    print(f"Average Error: {average_error}, Standard Deviation: {error_std_dev}")

    return average_error, error_std_dev

def model_d(inputs=3):
    """Create a neural network model with:

    - Three hidden layers, each with 10 nodes using ReLU activation.
    - Adam optimizer and mean squared error as the loss function.
    """

    # Initialize the neural network
    model = Sequential()

    # Adds hidden layers with ReLU activation and 10 nodes
    model.add(Dense(10, activation="relu", input_shape=(inputs,)))
    model.add(Dense(10, activation="relu"))
    model.add(Dense(10, activation="relu"))

    # Adds output layer
    model.add(Dense(1))

    # Compiles the model with the 'adam' optimizer and loss function (MSE)
    model.compile(optimizer='adam', loss='mean_squared_error')

    return model

# %% [markdown]
# ## Loading the dataset

# %% [markdown]
# If the file path exists, we will load its contents into the DataFrame.

# %%
file_path = "/concrete_data.csv" # This can depend on where you saved the csv file. **Change might be needed **
# Loads the data into a DataFrame
df = load_data(file_path)
# Out:
# Loading data from the file'/concrete_data.csv'

# %% [markdown]
# ## Validating the dataset

# %%
df.columns # We check the columns of the df
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %%
df.describe() # key statistical measures (Count, Mean, etc...)
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# 25%            0.000000        932.000000      730.950000     7.000000
# 50%            6.400000        968.000000      779.500000    28.000000
# 75%           10.200000       1029.400000      824.000000    56.000000
# max           32.200000       1145.000000      992.600000   365.000000
#
#           Strength
# count  1030.000000
# mean     35.817961
# std      16.705742
# min       2.330000
# 25%      23.710000
# 50%      34.445000
# 75%      46.135000
# max      82.600000

# %%
df.info() # Provides a concise summary of the DataFrame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1030 entries, 0 to 1029
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Cement              1030 non-null   float64
#  1   Blast Furnace Slag  1030 non-null   float64
#  2   Fly Ash             1030 non-null   float64
#  3   Water               1030 non-null   float64
#  4   Superplasticizer    1030 non-null   float64
#  5   Coarse Aggregate    1030 non-null   float64
#  6   Fine Aggregate      1030 non-null   float64
#  7   Age                 1030 non-null   int64
#  8   Strength            1030 non-null   float64
# dtypes: float64(8), int64(1)
# memory usage: 72.5 KB

# %% [markdown]
# We will be splitting the data into training and testing sets, holding 30% of the data for testing.

# %%
print(f"DataFrame dimensions: Rows={df.shape[0]}, Columns={df.shape[1]}") # Displayes the shape of the DataFrame
# Out:
# DataFrame dimensions: Rows=1030, Columns=9

# %%
# Now we will check if there is any data missing
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %% [markdown]
# As we can see, the data is all loaded and good to go. Now we will normalize the data to ensure that all the features have the same data scale. This is important to improve the performance and stability of the machine learning models.

# %% [markdown]
# ## Splitting the dataset into training and testing sets

# %%
# Here we show all the columns of the df
columns = df.columns
print(columns)
# Out:
# Index(['Cement', 'Blast Furnace Slag', 'Fly Ash', 'Water', 'Superplasticizer',
#        'Coarse Aggregate', 'Fine Aggregate', 'Age', 'Strength'],
#       dtype='object')

# %% [markdown]
# ### We will now split the data into predictors and targets

# %%
# Here we extract the predictors, excluding the 'Strength' column, which will be the target
strength_column = "Strength"
column_predictors = [col for col in columns if col != strength_column]
predictor_df = df[column_predictors]
predictor_df.head(4) # We show the first 4 rows of the predictor's df
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365

# %%
# Here we will select the 'Strength' column to be our target df
target_df = df[[strength_column]]
target_df.head(4) # We show the first 4 rows of the target's df
# Out:
#    Strength
# 0     79.99
# 1     61.89
# 2     40.27
# 3     41.05

# %% [markdown]
# # A. Build a baseline model
#
# ### Requirements:
#
# Use the Keras library to build a neural network with the following:
#
# - One hidden layer of 10 nodes, and a ReLU activation function
#
# - Use the adam optimizer and the mean squared error  as the loss function.
#
# 1. Randomly split the data into a training and test sets by holding 30% of the data for testing. You can use the
# train_test_split
# helper function from Scikit-learn.
#
# 2. Train the model on the training data using 50 epochs.
#
# 3. Evaluate the model on the test data and compute the mean squared error between the predicted concrete strength and the actual concrete strength. You can use the mean_squared_error function from Scikit-learn.
#
# 4. Repeat steps 1 - 3, 50 times, i.e., create a list of 50 mean squared errors.
#
# 5. Report the mean and the standard deviation of the mean squared errors.
#
# Submit your Jupyter Notebook with your code and comments.

# %% [markdown]
# ### Here we build and train the model

# %%
compiled_model = model_a(inputs=len(column_predictors))
print(len(column_predictors))
# Out:
# 8
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
iterations = 50
epochs = 50
verbose = 0

# We compile the model...
average_mean_squared_error_A, error_deviation_A = calculate_error_stats(
    inputs=predictor_df,
    target_values=target_df,
    model=compiled_model,
    iterations=iterations,
    epochs=epochs,
    verbose=verbose
)
# Out:
# ----------------------------------------
# Starting iteration: 1
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Iteration finished in 3.76 seconds.
# ----------------------------------------
# Starting iteration: 2
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 2.94 seconds.
# ----------------------------------------
# Starting iteration: 3
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.35 seconds.
# ----------------------------------------
# Starting iteration: 4
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.92 seconds.
# ----------------------------------------
# Starting iteration: 5
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.00 seconds.
# ----------------------------------------
# Starting iteration: 6
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.11 seconds.
# ----------------------------------------
# Starting iteration: 7
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.25 seconds.
# ----------------------------------------
# Starting iteration: 8
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.03 seconds.
# ----------------------------------------
# Starting iteration: 9
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.11 seconds.
# ----------------------------------------
# Starting iteration: 10
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 4.39 seconds.
# ----------------------------------------
# Starting iteration: 11
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.05 seconds.
# ----------------------------------------
# Starting iteration: 12
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.02 seconds.
# ----------------------------------------
# Starting iteration: 13
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.15 seconds.
# ----------------------------------------
# Starting iteration: 14
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.40 seconds.
# ----------------------------------------
# Starting iteration: 15
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.12 seconds.
# ----------------------------------------
# Starting iteration: 16
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.01 seconds.
# ----------------------------------------
# Starting iteration: 17
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.02 seconds.
# ----------------------------------------
# Starting iteration: 18
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.26 seconds.
# ----------------------------------------
# Starting iteration: 19
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.05 seconds.
# ----------------------------------------
# Starting iteration: 20
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.02 seconds.
# ----------------------------------------
# Starting iteration: 21
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.27 seconds.
# ----------------------------------------
# Starting iteration: 22
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.02 seconds.
# ----------------------------------------
# Starting iteration: 23
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.05 seconds.
# ----------------------------------------
# Starting iteration: 24
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.17 seconds.
# ----------------------------------------
# Starting iteration: 25
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.23 seconds.
# ----------------------------------------
# Starting iteration: 26
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.91 seconds.
# ----------------------------------------
# Starting iteration: 27
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.98 seconds.
# ----------------------------------------
# Starting iteration: 28
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.62 seconds.
# ----------------------------------------
# Starting iteration: 29
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.88 seconds.
# ----------------------------------------
# Starting iteration: 30
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.01 seconds.
# ----------------------------------------
# Starting iteration: 31
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 32
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.30 seconds.
# ----------------------------------------
# Starting iteration: 33
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.93 seconds.
# ----------------------------------------
# Starting iteration: 34
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.96 seconds.
# ----------------------------------------
# Starting iteration: 35
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.93 seconds.
# ----------------------------------------
# Starting iteration: 36
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.39 seconds.
# ----------------------------------------
# Starting iteration: 37
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.10 seconds.
# ----------------------------------------
# Starting iteration: 38
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.01 seconds.
# ----------------------------------------
# Starting iteration: 39
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.10 seconds.
# ----------------------------------------
# Starting iteration: 40
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.23 seconds.
# ----------------------------------------
# Starting iteration: 41
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.99 seconds.
# ----------------------------------------
# Starting iteration: 42
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.07 seconds.
# ----------------------------------------
# Starting iteration: 43
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 4.36 seconds.
# ----------------------------------------
# Starting iteration: 44
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.08 seconds.
# ----------------------------------------
# Starting iteration: 45
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.91 seconds.
# ----------------------------------------
# Starting iteration: 46
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.93 seconds.
# ----------------------------------------
# Starting iteration: 47
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.27 seconds.
# ----------------------------------------
# Starting iteration: 48
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 49
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 50
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.90 seconds.
# Completed 50 iterations. Error list: [483.046324963723, 151.80251526700695, 114.97411878794605, 108.3594521218885, 110.68897340972181, 112.44431147186694, 108.25048572293693, 112.66623309031286, 107.30136685879879, 104.27735888701291, 104.00349125827779, 91.94132229924564, 67.82762694163223, 54.29615946989094, 54.82213922761644, 48.136842505008026, 50.27331505477153, 48.0424400041621, 51.288787833162765, 52.99658995395505, 58.00743243654782, 48.40215349382387, 51.21402034838871, 52.126919512668266, 54.68184728644812, 55.288315191682315, 48.11604673463787, 63.20719057514062, 50.894017881311356, 49.07244086731189, 50.56360533516816, 52.910342620009054, 53.25513065336911, 50.405154079533, 49.472022970405796, 48.3942304312279, 49.598463908957974, 48.977539892186584, 48.7252368588549, 50.154228903210836, 49.58926369467331, 50.08605472537867, 53.42662050581387, 51.49088436831201, 48.21151319814801, 69.08570346552769, 49.847524530816294, 55.97713671433414, 64.26550849639291, 48.360742278335934]
# ----------------------------------------------------------------------
# Average Error: 74.22, Standard Deviation: 63.77

# %% [markdown]
# ## Report for model A

# %%
experiment = "A) - Baseline Raw model (50 epochs)"
results_a_df = report(experiment, average_mean_squared_error_A, error_deviation_A)
results_a_df
# Out:
#                             Experiment  Average Error (Mean MSE)  \
# 0  A) - Baseline Raw model (50 epochs)                     74.22
#
#    Error Deviation (Deviation MSE)
# 0                            63.77

# %% [markdown]
# # B. Normalize the data
# Repeat Part A but use a normalized version of the data. Recall that one way to normalize the data is by subtracting the mean from the individual predictors and dividing by the standard deviation.
#
# How does the mean of the mean squared errors compare to that from Step A?

# %% [markdown]
# ### Data before normalizing

# %%
predictor_df.head(4) # We show the first 4 rows of the predictor's df
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
# 2   332.5               142.5      0.0  228.0               0.0
# 3   332.5               142.5      0.0  228.0               0.0
#
#    Coarse Aggregate  Fine Aggregate  Age
# 0            1040.0           676.0   28
# 1            1055.0           676.0   28
# 2             932.0           594.0  270
# 3             932.0           594.0  365

# %% [markdown]
# ### Now we will normalize the input data
# We normalize the data by subtracting the mean from each predictor and dividing the result by its standard deviation.

# %%
predictor_df_normalized = (predictor_df - predictor_df.mean()) / predictor_df.std()
predictor_df_normalized.head(4) # We show the first 4 rows of the normalized predictor's df
# Out:
#      Cement  Blast Furnace Slag   Fly Ash     Water  Superplasticizer  \
# 0  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 1  2.476712           -0.856472 -0.846733 -0.916319         -0.620147
# 2  0.491187            0.795140 -0.846733  2.174405         -1.038638
# 3  0.491187            0.795140 -0.846733  2.174405         -1.038638
#
#    Coarse Aggregate  Fine Aggregate       Age
# 0          0.862735       -1.217079 -0.279597
# 1          1.055651       -1.217079 -0.279597
# 2         -0.526262       -2.239829  3.551340
# 3         -0.526262       -2.239829  5.055221

# %%
iterations = 50
epochs = 50
verbose = 0


compiled_model = model_a(inputs=len(column_predictors))

# We compile the model...
average_mean_squared_error_B, error_deviation_B = calculate_error_stats(
    inputs=predictor_df_normalized,
    target_values=target_df,
    model=compiled_model,
    iterations=iterations,
    epochs=epochs,
    verbose=verbose
)
# Out:
# ----------------------------------------
# Starting iteration: 1
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Iteration finished in 4.90 seconds.
# ----------------------------------------
# Starting iteration: 2
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.90 seconds.
# ----------------------------------------
# Starting iteration: 3
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.87 seconds.
# ----------------------------------------
# Starting iteration: 4
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.95 seconds.
# ----------------------------------------
# Starting iteration: 5
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.16 seconds.
# ----------------------------------------
# Starting iteration: 6
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.90 seconds.
# ----------------------------------------
# Starting iteration: 7
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 2.92 seconds.
# ----------------------------------------
# Starting iteration: 8
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.24 seconds.
# ----------------------------------------
# Starting iteration: 9
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.03 seconds.
# ----------------------------------------
# Starting iteration: 10
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.90 seconds.
# ----------------------------------------
# Starting iteration: 11
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.99 seconds.
# ----------------------------------------
# Starting iteration: 12
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.50 seconds.
# ----------------------------------------
# Starting iteration: 13
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.04 seconds.
# ----------------------------------------
# Starting iteration: 14
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.85 seconds.
# ----------------------------------------
# Starting iteration: 15
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.97 seconds.
# ----------------------------------------
# Starting iteration: 16
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 4.24 seconds.
# ----------------------------------------
# Starting iteration: 17
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.94 seconds.
# ----------------------------------------
# Starting iteration: 18
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.02 seconds.
# ----------------------------------------
# Starting iteration: 19
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.59 seconds.
# ----------------------------------------
# Starting iteration: 20
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.74 seconds.
# ----------------------------------------
# Starting iteration: 21
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.99 seconds.
# ----------------------------------------
# Starting iteration: 22
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.01 seconds.
# ----------------------------------------
# Starting iteration: 23
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.15 seconds.
# ----------------------------------------
# Starting iteration: 24
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.20 seconds.
# ----------------------------------------
# Starting iteration: 25
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.94 seconds.
# ----------------------------------------
# Starting iteration: 26
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.98 seconds.
# ----------------------------------------
# Starting iteration: 27
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 4.45 seconds.
# ----------------------------------------
# Starting iteration: 28
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.05 seconds.
# ----------------------------------------
# Starting iteration: 29
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.11 seconds.
# ----------------------------------------
# Starting iteration: 30
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.15 seconds.
# ----------------------------------------
# Starting iteration: 31
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.24 seconds.
# ----------------------------------------
# Starting iteration: 32
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.04 seconds.
# ----------------------------------------
# Starting iteration: 33
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.01 seconds.
# ----------------------------------------
# Starting iteration: 34
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.96 seconds.
# ----------------------------------------
# Starting iteration: 35
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.26 seconds.
# ----------------------------------------
# Starting iteration: 36
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 37
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.18 seconds.
# ----------------------------------------
# Starting iteration: 38
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.35 seconds.
# ----------------------------------------
# Starting iteration: 39
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.90 seconds.
# ----------------------------------------
# Starting iteration: 40
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 41
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.00 seconds.
# ----------------------------------------
# Starting iteration: 42
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.27 seconds.
# ----------------------------------------
# Starting iteration: 43
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.99 seconds.
# ----------------------------------------
# Starting iteration: 44
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.04 seconds.
# ----------------------------------------
# Starting iteration: 45
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Iteration finished in 3.77 seconds.
# ----------------------------------------
# Starting iteration: 46
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.63 seconds.
# ----------------------------------------
# Starting iteration: 47
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.02 seconds.
# ----------------------------------------
# Starting iteration: 48
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 2.97 seconds.
# ----------------------------------------
# Starting iteration: 49
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.42 seconds.
# ----------------------------------------
# Starting iteration: 50
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.09 seconds.
# Completed 50 iterations. Error list: [300.1740934760005, 143.52024237526592, 104.02379268613542, 79.83090483742781, 66.39895972075256, 56.32259399791259, 48.83644966536474, 44.831006204622724, 42.29332355933434, 41.12687511999789, 40.348550490714324, 39.97655923752655, 39.86850546601899, 39.75793730207685, 39.65994163443253, 39.779771634047535, 39.984373598338735, 39.83646360104778, 39.88883623007663, 39.96381624424572, 39.91646715248198, 40.01586810228646, 40.019562481667094, 40.12292183745562, 40.05598469866539, 40.072675691815796, 40.02367506943804, 39.88826348625828, 39.72086979556632, 39.558291876200535, 39.508604007565566, 39.44627633738284, 39.60904204110015, 39.245572925656596, 39.11344258319405, 38.926433177698314, 38.92834694567575, 39.002476476741876, 38.90304700574062, 38.892457270283174, 38.98467796956646, 38.991413587310596, 38.90438483258224, 39.109925265992864, 39.05502531641014, 39.189676382855374, 39.172611637292405, 39.31490077008773, 39.35448864986251, 39.31705417952771]
# ----------------------------------------------------------------------
# Average Error: 50.18, Standard Deviation: 40.0

# %% [markdown]
# ## Report for model B

# %%
experiment = "B) Normalized model (50 epochs)"
results_b_df = report(experiment, average_mean_squared_error_B, error_deviation_B)
results_b_df
# Out:
#                         Experiment  Average Error (Mean MSE)  \
# 0  B) Normalized model (50 epochs)                     50.18
#
#    Error Deviation (Deviation MSE)
# 0                             40.0

# %% [markdown]
# # C. Increate the number of epochs
# Repeat Part B but use 100 epochs this time for training.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
iterations = 50
epochs = 100
verbose = 0


compiled_model = model_a(inputs=len(column_predictors))

# We compile the model...
average_mean_squared_error_c, error_deviation_c = calculate_error_stats(
    inputs=predictor_df_normalized,
    target_values=target_df,
    model=compiled_model,
    iterations=iterations,
    epochs=epochs,
    verbose=verbose
)
# Out:
# ----------------------------------------
# Starting iteration: 1
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Iteration finished in 6.98 seconds.
# ----------------------------------------
# Starting iteration: 2
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 6.56 seconds.
# ----------------------------------------
# Starting iteration: 3
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Iteration finished in 6.65 seconds.
# ----------------------------------------
# Starting iteration: 4
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.13 seconds.
# ----------------------------------------
# Starting iteration: 5
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.06 seconds.
# ----------------------------------------
# Starting iteration: 6
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.41 seconds.
# ----------------------------------------
# Starting iteration: 7
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.17 seconds.
# ----------------------------------------
# Starting iteration: 8
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.53 seconds.
# ----------------------------------------
# Starting iteration: 9
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Iteration finished in 6.45 seconds.
# ----------------------------------------
# Starting iteration: 10
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.29 seconds.
# ----------------------------------------
# Starting iteration: 11
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.75 seconds.
# ----------------------------------------
# Starting iteration: 12
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.18 seconds.
# ----------------------------------------
# Starting iteration: 13
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 7.30 seconds.
# ----------------------------------------
# Starting iteration: 14
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.74 seconds.
# ----------------------------------------
# Starting iteration: 15
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.93 seconds.
# ----------------------------------------
# Starting iteration: 16
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 5.66 seconds.
# ----------------------------------------
# Starting iteration: 17
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.07 seconds.
# ----------------------------------------
# Starting iteration: 18
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.74 seconds.
# ----------------------------------------
# Starting iteration: 19
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.21 seconds.
# ----------------------------------------
# Starting iteration: 20
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.96 seconds.
# ----------------------------------------
# Starting iteration: 21
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.37 seconds.
# ----------------------------------------
# Starting iteration: 22
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.93 seconds.
# ----------------------------------------
# Starting iteration: 23
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.28 seconds.
# ----------------------------------------
# Starting iteration: 24
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.76 seconds.
# ----------------------------------------
# Starting iteration: 25
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.45 seconds.
# ----------------------------------------
# Starting iteration: 26
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.96 seconds.
# ----------------------------------------
# Starting iteration: 27
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.27 seconds.
# ----------------------------------------
# Starting iteration: 28
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.28 seconds.
# ----------------------------------------
# Starting iteration: 29
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 6.59 seconds.
# ----------------------------------------
# Starting iteration: 30
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.87 seconds.
# ----------------------------------------
# Starting iteration: 31
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.29 seconds.
# ----------------------------------------
# Starting iteration: 32
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.12 seconds.
# ----------------------------------------
# Starting iteration: 33
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.87 seconds.
# ----------------------------------------
# Starting iteration: 34
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 7.22 seconds.
# ----------------------------------------
# Starting iteration: 35
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.73 seconds.
# ----------------------------------------
# Starting iteration: 36
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.07 seconds.
# ----------------------------------------
# Starting iteration: 37
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.03 seconds.
# ----------------------------------------
# Starting iteration: 38
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.21 seconds.
# ----------------------------------------
# Starting iteration: 39
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.92 seconds.
# ----------------------------------------
# Starting iteration: 40
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.10 seconds.
# ----------------------------------------
# Starting iteration: 41
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.88 seconds.
# ----------------------------------------
# Starting iteration: 42
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.17 seconds.
# ----------------------------------------
# Starting iteration: 43
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.96 seconds.
# ----------------------------------------
# Starting iteration: 44
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.28 seconds.
# ----------------------------------------
# Starting iteration: 45
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 5.87 seconds.
# ----------------------------------------
# Starting iteration: 46
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 7.24 seconds.
# ----------------------------------------
# Starting iteration: 47
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.42 seconds.
# ----------------------------------------
# Starting iteration: 48
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.63 seconds.
# ----------------------------------------
# Starting iteration: 49
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.56 seconds.
# ----------------------------------------
# Starting iteration: 50
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 6.28 seconds.
# Completed 50 iterations. Error list: [141.81177158605993, 84.94185159473008, 60.68065411306852, 43.317540282474354, 39.69540413083026, 39.0661900821058, 38.76306663946066, 38.936497510023386, 39.07249424939723, 39.09955796701486, 39.284152066920626, 39.230508115292295, 39.12481389503064, 39.0163923938189, 38.766191062540706, 38.78645915903258, 38.702249363507434, 38.67973890888626, 38.531974452671605, 38.53319464153141, 38.4197383799556, 38.506405407417255, 38.47518877242541, 38.36813101209291, 38.64322562607243, 38.49917068285494, 38.64970805220007, 38.65694378754871, 38.51689389215059, 38.56076013231927, 38.572457503431394, 38.57785494960598, 38.715573024229414, 38.69085520422439, 38.612106133682204, 38.66597557974498, 38.657768265035706, 38.64930721320454, 38.516781883865114, 38.67517692499082, 38.538653859995115, 38.596222268359234, 38.60068238749739, 38.596890031328456, 38.63668058185492, 38.66836022957777, 38.67030748607872, 38.57766680877285, 38.75200766882032, 38.76266285712282]
# ----------------------------------------------------------------------
# Average Error: 42.24, Standard Deviation: 15.91

# %% [markdown]
# ## Report for model C

# %%
experiment = "C) Normalized model (100 epochs)"
results_c_df = report(experiment, average_mean_squared_error_c, error_deviation_c)
results_c_df
# Out:
#                          Experiment  Average Error (Mean MSE)  \
# 0  C) Normalized model (100 epochs)                     42.24
#
#    Error Deviation (Deviation MSE)
# 0                            15.91

# %% [markdown]
# # D. Increase the number of hidden layers
# Repeat part B but use a neural network with the following instead:
#
# - Three hidden layers, each of 10 nodes and ReLU activation function.
#
# How does the mean of the mean squared errors compare to that from Step B?

# %%
iterations = 50
epochs = 50
verbose = 0


compiled_model = model_d(inputs=len(column_predictors))

# We compile the model...
average_mean_squared_error_d, error_deviation_d = calculate_error_stats(
    inputs=predictor_df_normalized,
    target_values=target_df,
    model=compiled_model,
    iterations=iterations,
    epochs=epochs,
    verbose=verbose
)
# Out:
# ----------------------------------------
# Starting iteration: 1
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# Iteration finished in 4.40 seconds.
# ----------------------------------------
# Starting iteration: 2
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.55 seconds.
# ----------------------------------------
# Starting iteration: 3
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.98 seconds.
# ----------------------------------------
# Starting iteration: 4
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.13 seconds.
# ----------------------------------------
# Starting iteration: 5
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.94 seconds.
# ----------------------------------------
# Starting iteration: 6
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.46 seconds.
# ----------------------------------------
# Starting iteration: 7
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.12 seconds.
# ----------------------------------------
# Starting iteration: 8
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.07 seconds.
# ----------------------------------------
# Starting iteration: 9
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.50 seconds.
# ----------------------------------------
# Starting iteration: 10
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.04 seconds.
# ----------------------------------------
# Starting iteration: 11
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.98 seconds.
# ----------------------------------------
# Starting iteration: 12
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.03 seconds.
# ----------------------------------------
# Starting iteration: 13
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.39 seconds.
# ----------------------------------------
# Starting iteration: 14
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.14 seconds.
# ----------------------------------------
# Starting iteration: 15
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.86 seconds.
# ----------------------------------------
# Starting iteration: 16
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Iteration finished in 3.70 seconds.
# ----------------------------------------
# Starting iteration: 17
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.65 seconds.
# ----------------------------------------
# Starting iteration: 18
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.05 seconds.
# ----------------------------------------
# Starting iteration: 19
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.01 seconds.
# ----------------------------------------
# Starting iteration: 20
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.53 seconds.
# ----------------------------------------
# Starting iteration: 21
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.04 seconds.
# ----------------------------------------
# Starting iteration: 22
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.07 seconds.
# ----------------------------------------
# Starting iteration: 23
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.13 seconds.
# ----------------------------------------
# Starting iteration: 24
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.43 seconds.
# ----------------------------------------
# Starting iteration: 25
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.11 seconds.
# ----------------------------------------
# Starting iteration: 26
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# Iteration finished in 3.11 seconds.
# ----------------------------------------
# Starting iteration: 27
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.37 seconds.
# ----------------------------------------
# Starting iteration: 28
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.11 seconds.
# ----------------------------------------
# Starting iteration: 29
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.02 seconds.
# ----------------------------------------
# Starting iteration: 30
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.01 seconds.
# ----------------------------------------
# Starting iteration: 31
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.42 seconds.
# ----------------------------------------
# Starting iteration: 32
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 33
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 34
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.15 seconds.
# ----------------------------------------
# Starting iteration: 35
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.22 seconds.
# ----------------------------------------
# Starting iteration: 36
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.09 seconds.
# ----------------------------------------
# Starting iteration: 37
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.06 seconds.
# ----------------------------------------
# Starting iteration: 38
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.44 seconds.
# ----------------------------------------
# Starting iteration: 39
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.09 seconds.
# ----------------------------------------
# Starting iteration: 40
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.15 seconds.
# ----------------------------------------
# Starting iteration: 41
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.97 seconds.
# ----------------------------------------
# Starting iteration: 42
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.39 seconds.
# ----------------------------------------
# Starting iteration: 43
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.08 seconds.
# ----------------------------------------
# Starting iteration: 44
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.16 seconds.
# ----------------------------------------
# Starting iteration: 45
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.54 seconds.
# ----------------------------------------
# Starting iteration: 46
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.80 seconds.
# ----------------------------------------
# Starting iteration: 47
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.09 seconds.
# ----------------------------------------
# Starting iteration: 48
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 3.13 seconds.
# ----------------------------------------
# Starting iteration: 49
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 4.54 seconds.
# ----------------------------------------
# Starting iteration: 50
# Training set size: (721, 8), (721, 1)
# Testing set size: (309, 8), (309, 1)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Iteration finished in 2.99 seconds.
# Completed 50 iterations. Error list: [139.5687913311468, 115.3210313329252, 83.97200801997704, 46.98851086518942, 43.57205744903042, 41.22206238666108, 40.996650944823365, 40.31434411654648, 39.36319304506172, 38.51875766533593, 38.39951825044914, 38.23606412809158, 37.813852711637715, 37.00750570170436, 36.61287182124679, 36.5633429745438, 36.89928378962754, 35.61040428630923, 35.785178822589884, 34.66981848155869, 34.643302398343856, 35.20699216839522, 34.587176386927965, 33.86378386626153, 34.302328934158574, 34.65362517620467, 34.43538777915846, 33.73769924263266, 34.01849582583801, 33.64926092789335, 33.88602801863883, 33.90457464350888, 33.990333153541926, 33.72186155298782, 33.5129694773965, 33.00717563289216, 33.52868057711074, 32.67612647186872, 33.336493211515005, 34.55200811502191, 32.51117631313418, 32.82927353211062, 33.063622207848965, 32.76964463017726, 33.23468298825623, 32.95408887045697, 33.06536642379327, 33.23960673761149, 32.68610773294656, 33.42299107214486]
# ----------------------------------------------------------------------
# Average Error: 40.13, Standard Deviation: 19.46

# %% [markdown]
# ## Report for model D

# %%
experiment = "D) Normalized model 3 hidden layers (50 epochs)"
results_d_df = report(experiment, average_mean_squared_error_d, error_deviation_d)
results_d_df
# Out:
#                                         Experiment  Average Error (Mean MSE)  \
# 0  D) Normalized model 3 hidden layers (50 epochs)                     40.13
#
#    Error Deviation (Deviation MSE)
# 0                            19.46

# %% [markdown]
# # Final results

# %%
final_results_df = pd.concat([results_a_df, results_b_df, results_c_df, results_d_df], ignore_index=True)

# We Display the combined DataFrame
final_results_df
# Out:
#                                         Experiment  Average Error (Mean MSE)  \
# 0              A) - Baseline Raw model (50 epochs)                     74.22
# 1                  B) Normalized model (50 epochs)                     50.18
# 2                 C) Normalized model (100 epochs)                     42.24
# 3  D) Normalized model 3 hidden layers (50 epochs)                     40.13
#
#    Error Deviation (Deviation MSE)
# 0                            63.77
# 1                            40.00
# 2                            15.91
# 3                            19.46

# %% [markdown]
# The mean squared error (MSE) is an essential metric used to evaluate how well a regression model fits the testing data. A lower MSE means the model predicts more accurately. The standard deviation (Deviation MSE) reflects the consistency of the model's predictions.
#
# **1. Model A - Baseline Raw Model (50 epochs):**
#
# - This model has the highest mean MSE (74.22) and a very large deviation (63.77). This indicates that without normalization, the model struggles with both accuracy and consistency.
#
# **2. Model B - Normalized Model (50 epochs):**
# - After applying normalization, the mean MSE significantly drops to 50.18, with a reduced error deviation of 40.00. Normalizing the data improves the model's performance by making it more accurate and consistent.
#
# **3. Model C - Normalized Model (100 epochs):**
# - With the same single hidden layer but double the epochs (100), the mean MSE decreases further to 42.24, and the deviation reduces to 15.91. This demonstrates that increasing the number of epochs allows the model to learn better, resulting in higher accuracy and more consistent predictions with a lower error deviation.
#
# **4. Model D - Normalized Model with 3 Hidden Layers (50 epochs):**
# - This model achieves the best performance, with the lowest mean MSE (40.13) and a small error deviation (19.46). Using three hidden layers improves the model's ability to capture complex patterns in the data, even with only 50 epochs.
#
#
# **Conclusion:**
# Experimenting with techniques such as normalizing the input data, increasing the number of epochs to balance accuracy and training time, and adding more hidden layers to improve the model's capacity to capture complex relationships in the data can help achieve the best results.
